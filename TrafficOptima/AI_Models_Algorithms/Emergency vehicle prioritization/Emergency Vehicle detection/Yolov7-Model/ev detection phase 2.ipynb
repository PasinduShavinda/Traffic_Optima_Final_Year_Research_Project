# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive
# Out:
# /content/gdrive/MyDrive

# %%
# %cd SirenDitection
# Out:
# /content/gdrive/MyDrive/SirenDitection

# %%
# %cd yolov7
# Out:
# /content/gdrive/MyDrive/SirenDitection/yolov7

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/SirenDitection/yolov7

# %%
# !python train.py --device 0 --batch-size 32 --epochs 40 --img 416 --data data/coco-custom.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights yolov7.pt --name yolov7-custom-2
# Out:
# 2023-05-22 00:03:14.255792: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-22 00:03:15.772680: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# YOLOR 🚀 v0.1-122-g3b41c2c torch 2.0.1+cu118 CUDA:0 (Tesla T4, 15101.8125MB)
#
# ...

# %%
# !python detect.py --weights runs/train/yolov7-custom-2/weights/best.pt --img-size 416 --source /content/gdrive/MyDrive/SirenDitection/videoplayback.mp4 --no-trace
# Out:
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/usr/local/lib/python3.10/dist-packages/IPython/terminal/ipapp.py", line 29, in <module>
#     from IPython.core.magics import (
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magics/__init__.py", line 28, in <module>
#     from .pylab import PylabMagics
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magics/pylab.py", line 38, in <module>
#     class PylabMagics(Magics):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/magics/pylab.py", line 47, in PylabMagics
#     def matplotlib(self, line=''):
# ...
