# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# %%
infer = YOLO("best.pt")
infer.predict("videoplayback4.mp4", save=True, conf=0.75)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1145) /Users/chamathkavindya/Ev prioratization/yolov8/videoplayback4.mp4: 384x640 (no detections), 90.9ms
# video 1/1 (2/1145) /Users/chamathkavindya/Ev prioratization/yolov8/videoplayback4.mp4: 384x640 (no detections), 79.6ms
# video 1/1 (3/1145) /Users/chamathkavindya/Ev prioratization/yolov8/videoplayback4.mp4: 384x640 (no detections), 66.6ms
# ...
